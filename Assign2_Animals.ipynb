# %%
# Polymorphism
class Animal:
    def init(self, name):
        self.name = name

    def speak(self):
        pass

class Dog(Animal):
    def speak(self):
        return "Woof!"

class Cat(Animal):
    def speak(self):
        return "Meowww!"

def animal_speak(animal):
    print(animal.speak())

dog = Dog("Tommy")
cat = Cat("Messy")

animal_speak(dog)
animal_speak(cat)  

# Types of Polymorphism

class Circle:
    def init(self, radius):
        self.radius = radius

    def area(self):
       print("The area of circle is:")
       return 3.14 * self.radius * self.radius

class Square:
    def init(self, side):
        self.side = side

    def area(self):
        print("The area of square is:")
        return self.side * self.side


shapes = [Circle(4), Square(5)]

for shape in shapes:
    print(shape.area())

class Person:
    def init(self, name):
        self.name = name

    def introduce(self):
        print(f"Hi, my name is {self.name}.")

    def introduce(self, age):
        print(f"Hi, my name is {self.name} and I am {age} years old.")

person = Person("Abc")
person.introduce(19) 


class Point:
    def init(self, x, y):
        self.x = x
        self.y = y

    def add(self, other):
        return Point(self.x + other.x, self.y + other.y)

    def str(self):
        return f"({self.x}, {self.y})"

p1 = Point(2, 3)
p2 = Point(4, 5)

print(p1 + p2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9700\2270768777.py in <module>
#      18     print(animal.speak())
#      19
# ---> 20 dog = Dog("Tommy")
#      21 cat = Cat("Messy")
#      22
#
# TypeError: Dog() takes no arguments
